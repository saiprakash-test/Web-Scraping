# %% [markdown]
# # IMDB TOP 100 MOVIES

# %%
# Importing Libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests
import selenium
from selenium import webdriver
import time

# %%
# Function Definition
def IMDB_top_100(url):
    r=requests.get(url)
    soup=BeautifulSoup(r.content,'html.parser')
    name=[]
    year=[]
    rating=[]
    for i in soup.find_all('img'):
        name.append(i.attrs['alt'])
    for i in list(soup.find_all('span',attrs={"secondaryInfo"})):
        year.append(i.text)
    for i in soup.find_all('strong'):
        rating.append(float(i.text))
    df=pd.DataFrame({'names':name[:100],
                     'years':year[:100],
                     'ratings':rating[:100]})
    print(df)
    df.to_csv('IMDB top 100 Movies.csv', index = False)

# Calling Function
IMDB_top_100("https://www.imdb.com/chart/top/")
# Out:
#                                     names   years  ratings
# 0                The Shawshank Redemption  (1994)      9.2
# 1                           The Godfather  (1972)      9.1
# 2                  The Godfather: Part II  (1974)      9.0
# 3                         The Dark Knight  (2008)      9.0
# 4                            12 Angry Men  (1957)      8.9
# ..                                    ...     ...      ...
# 95                           Idi i smotri  (1985)      8.3
# 96                    Requiem for a Dream  (2000)      8.3
# 97                    Singin' in the Rain  (1952)      8.3
# 98                     North by Northwest  (1959)      8.3
# 99  Eternal Sunshine of the Spotless Mind  (2004)      8.3
#
# [100 rows x 3 columns]

# %% [markdown]
# # IMDB TOP 100 INDIAN MOVIES

# %%
# Function Definition
def IMDB_top_100Indian(url):
    r=requests.get(url)
    soup=BeautifulSoup(r.content,'html.parser')
    name=[]
    year=[]
    rating=[]
    for i in soup.find_all('img'):
        name.append(i.attrs['alt'])
    for i in list(soup.find_all('span',attrs={"secondaryInfo"})):
        year.append(i.text)
    for i in soup.find_all('strong'):
        rating.append(float(i.text))
    df=pd.DataFrame({'names':name[:100],
                     'years':year[:100],
                     'ratings':rating[:100]})
    print(df)
    df.to_csv('IMDB top 100 Indian Movies.csv', index = False)

# Calling Function
IMDB_top_100Indian("https://www.imdb.com/india/top-rated-indian-movies/")
# Out:
#                        names   years  ratings
# 0                    Nayakan  (1987)      8.5
# 1          Pariyerum Perumal  (2018)      8.5
# 2                 Anbe Sivam  (2003)      8.5
# 3            Pather Panchali  (1955)      8.5
# 4                    Golmaal  (1979)      8.5
# ..                       ...     ...      ...
# 95                   Kahaani  (2012)      8.1
# 96           Andaz Apna Apna  (1994)      8.1
# 97  Uri: The Surgical Strike  (2018)      8.1
# 98                        PK  (2014)      8.1
# 99                     Lucia  (2013)      8.1
#
# [100 rows x 3 columns]

# %% [markdown]
# # IMDB TOP 100 TV SHOWS

# %%
# Opening the Chromedriver
driver = webdriver.Chrome("chromedriver.exe")

# %%
# Opening the IMDB website
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
# Scraping the title of the webseries
title=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
# Scraping the year span of the webseries
year=driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
# Scraping the genre of the webseries
genre=driver.find_elements_by_xpath("//p[@class='text-muted text-small']/span[5]")
# Scraping the runtime of the webseries
runtime = driver.find_elements_by_xpath("//p[@class='text-muted text-small']/span[3]")
# Scraping the tratings of the webseries
ratings=driver.find_elements_by_xpath('//div[@class="ipl-rating-widget"]/div[1]')
# Scraping the votes of the webseries
votes=driver.find_elements_by_xpath('//div[@class="lister-item-content"]/p[4]/span[2]')

#Making a list and storing all the scraped titles into it
Title=[]
for i in title:
    if i.text is None :
        Title.append("-") 
    else:
        Title.append(i.text)
#Making a list and storing all the scraped years into it
Year=[]    
for i in year:
    if i.text is None :
        Year.append("-") 
    else:
        Year.append(i.text)
#Making a list and storing all the scraped genres into it        
Genre=[]
for i in genre:
    if i.text is None :
        Genre.append("-") 
    else:
        Genre.append(i.text)
#Making a list and storing all the scraped runtime into it        
Runtime=[]
for i in runtime:
    if i.text is None :
        Runtime.append("-") 
    else:
        Runtime.append(i.text)
#Making a list and storing all the scraped ratingss into it        
Ratings=[]
for i in ratings:
    if i.text is None :
        Ratings.append("-") 
    else:
        Ratings.append(i.text)
#Making a list and storing all the scraped votes into it        
Votes=[]
for i in votes:
    if i.text is None :
        Votes.append("-") 
    else:
        Votes.append(i.text)

# %%
#Saving all the scraped data into a DataFrame
Series=pd.DataFrame({})
Series['Title']=Title 
Series['Year span']=Year
Series['Genre']=Genre
Series['Run time']=Runtime
Series['Ratings']=Ratings
Series['Votes']=Votes
#Viewing the DataFrame
Series
# Out:
#                              Title    Year span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run time Ratings      Votes
# 0    57 min     9.2  1,836,498
# 1    51 min     8.7    875,188
# 2    44 min     8.2    879,840
# 3    60 min     7.6    264,331
# 4    43 min     7.6    225,812
# ..      ...     ...        ...
# 95   42 min     7.5     44,796
# 96   50 min     7.8     55,426
# 97   42 min     8.1    169,777
# 98   45 min     7.1     35,141
# 99  572 min     8.6    193,476
#
# [100 rows x 6 columns]

# %%
Series.to_csv("IMDB top 100 TV Shows.csv", index = False)

# %%
# Closing the driver
driver.close()
